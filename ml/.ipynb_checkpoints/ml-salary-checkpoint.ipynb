# %%
import pybaseball as ball
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.impute import SimpleImputer
# %matplotlib inline

# %% [markdown]
# ## Data Cleaning and Dataframe Creation

# %%
salaries = []
years = ['19','18','17','16','15','14']

# %%
for year in years:
    url = 'https://www.usatoday.com/sports/mlb/salaries/' + year + '/player/all/'
    df = pd.read_html(url)
    salaries.append(df[0])

# %%
batters19 = pd.read_csv('stat_files/b19.csv')
batters18 = pd.read_csv('stat_files/b18.csv')
batters17 = pd.read_csv('stat_files/b17.csv')
batters16 = pd.read_csv('stat_files/b16.csv')
batters15 = pd.read_csv('stat_files/b15.csv')
batters14 = pd.read_csv('stat_files/b14.csv')
pitchers19 = pd.read_csv('stat_files/p19.csv')
pitchers18 = pd.read_csv('stat_files/p18.csv')
pitchers17 = pd.read_csv('stat_files/p17.csv')
pitchers16 = pd.read_csv('stat_files/p16.csv')
pitchers15 = pd.read_csv('stat_files/p15.csv')
pitchers14 = pd.read_csv('stat_files/p14.csv')

# %%
batting_salaries = []
pitching_salaries = []

# %%
for i in salaries:
    df = i[['Name', 'POS', 'Avg Annual']]
    df.dropna()
    batting_salaries.append(df[(df['POS'] != 'SP') & (df['POS'] != 'RP')])
    pitching_salaries.append(df[(df['POS'] == 'SP') | (df['POS'] == 'RP')])

# %%
batting_stats = [batters19,batters18,batters17,batters16,batters15,batters14]
pitching_stats = [pitchers19,pitchers18,pitchers17,pitchers16,pitchers15,pitchers14]

# %%
combined_bats = []
combined_pitch = []

# %%
for i in range(6):
    stats = batting_stats[i]
    salary = batting_salaries[i]
    combine = pd.merge(stats, salary, how='left', left_on=['Player'], right_on = ['Name'])
    combined_bats.append(combine)

# %%
for i in range(6):
    stats = pitching_stats[i]
    salary = pitching_salaries[i]
    combine = pd.merge(stats, salary, how='left', left_on=['Player'], right_on = ['Name'])
    combined_pitch.append(combine)

# %%
final_bat = pd.concat(combined_bats)
final_pitch = pd.concat(combined_pitch)

# %%
final_bat['Avg Annual'] = final_bat[final_bat.columns[-1]].replace('[\$,]', '', regex=True).astype(float)
final_pitch['Avg Annual'] = final_pitch[final_pitch.columns[-1]].replace('[\$,]', '', regex=True).astype(float)
final_bat.dropna()
final_pitch.dropna()
final_pitch.head(3)
# Out:
#              Player Team   G  GS  CG  SHO     IP    H  ER    K     ...      \
# 0  Justin Verlander  HOU  34  34   2    1  223.0  137  64  300     ...
# 1      Shane Bieber  CLE  34  33   3    2  214.1  186  78  259     ...
# 2       Gerrit Cole  HOU  33  33   0    0  212.1  142  59  326     ...
#
#     W  L  SV  BS  HLD   ERA  WHIP              Name  POS  Avg Annual
# 0  21  6   0   0    0  2.58  0.80  Justin Verlander   SP  25714286.0
# 1  15  8   0   0    0  3.28  1.05      Shane Bieber   SP    559600.0
# 2  20  5   0   0    0  2.50  0.89       Gerrit Cole   SP  13500000.0
#
# [3 rows x 22 columns]

# %%
# #filter out pitchers who have pitched less than 30 innings
# pfilter = final_pitch['IP'] > 30
# fpitch = final_pitch[pfilter]
# #filter out batters with less than 50 at bats
# bfilter = final_bat['AB'] > 50
# fbat = final_bat[bfilter]

# %%
fbat = final_bat.drop(['Name', 'POS'], axis = 1) 
fpitch = final_pitch.drop(['Name', 'POS'], axis = 1)

# %%
fbat = fbat.dropna()
fpitch = fpitch.dropna()

# %% [markdown]
# ## Batter Training

# %%
#creatings a veterans DF with players making over 5M
vets = fbat['Avg Annual'] >500000
vets = fbat[vets]
vets.head(3)
# Out:
#             Player Team Pos    G   AB    R    H  2B  3B  HR     ...      BB  \
# 0  Whit Merrifield   KC  2B  162  681  105  206  41  10  16     ...      45
# 1    Marcus Semien  OAK  SS  162  657  123  187  43   7  33     ...      87
# 2    Rafael Devers  BOS  3B  156  647  129  201  54   4  32     ...      48
#
#     SO  SH  SF  HBP    AVG    OBP    SLG    OPS  Avg Annual
# 0  126   0   4    5  0.302  0.348  0.463  0.811   4062500.0
# 1  102   0   1    2  0.285  0.369  0.522  0.891   5900000.0
# 2  119   1   2    4  0.311  0.361  0.555  0.916    614500.0
#
# [3 rows x 23 columns]

# %%
y=fbat['Avg Annual']
# X=fbat.iloc[:,3:-1]
X=fbat[['AB','H','HR','BB','SO','AVG','OBP','OPS']]

# %%
print(X.shape)
print(y.shape)
# Out:
# (2014, 8)
# (2014,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#       Coefficient
# AB   1.430221e+03
# H    3.391412e+04
# HR   1.676365e+05
# BB   9.108119e+04
# SO  -5.086228e+04
# AVG  5.635742e+06
# OBP -2.485727e+06
# OPS -1.369800e+06

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#          Actual     Predicted
# 122   9500000.0  1.035665e+07
# 636    567700.0  1.867268e+06
# 238   3750000.0  5.623378e+06
# 252   9700000.0  5.403119e+06
# 207   2500000.0  3.442770e+06
# 316   2500000.0  4.884487e+06
# 468    583600.0  2.238877e+06
# 27   15000000.0  9.349140e+06
# 16    5000000.0  1.032081e+07
# 205   5000000.0  5.896802e+06
# 283   4516667.0  3.616583e+06
# 24    6000000.0  1.007923e+07
# 162   8500000.0  6.829180e+06
# 576    556500.0  1.711366e+06
# 311   2212500.0  2.287622e+06
# 58    3300000.0  9.149833e+06
# 560   1200000.0  1.454916e+06
# 425    570000.0  2.543560e+06
# 135  10500000.0  1.024663e+07
# 34    5200000.0  1.488887e+07
# 152   4500000.0  7.126252e+06
# 142   8571429.0  7.061067e+06
# 54    8750000.0  9.625452e+06
# 252    567100.0  3.966882e+06
# 78   23000000.0  1.083652e+07
# 377   4500000.0  5.167592e+06
# 433  10333333.0  2.055400e+06
# 85    3500000.0  8.289598e+06
# 127   8666667.0  1.189713e+07
# 129   4500000.0  5.368396e+06
# ...

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4181054.44126706
# Mean Squared Error: 32827879335903.094
# Root Mean Squared Error: 5729561.879926168

# %%
np.sqrt(metrics.mean_squared_error(y_test, y_pred))/fbat['Avg Annual'].mean()
# Out:
# 0.9369834060467497

# %% [markdown]
# ## Pitcher Training

# %%
fpitch.head()
# Out:
#               Player Team   G  GS  CG  SHO     IP    H  ER    K  BB  HR   W  \
# 0   Justin Verlander  HOU  34  34   2    1  223.0  137  64  300  42  36  21
# 1       Shane Bieber  CLE  34  33   3    2  214.1  186  78  259  40  31  15
# 2        Gerrit Cole  HOU  33  33   0    0  212.1  142  59  326  48  29  20
# 3  Stephen Strasburg  WAS  33  33   0    0  209.0  161  77  251  56  24  18
# 4         Mike Minor  TEX  32  32   2    1  208.1  190  83  200  68  30  14
#
#     L  SV  BS  HLD   ERA  WHIP  Avg Annual
# 0   6   0   0    0  2.58  0.80  25714286.0
# 1   8   0   0    0  3.28  1.05    559600.0
# 2   5   0   0    0  2.50  0.89  13500000.0
# 3   6   0   0    0  3.32  1.04  25000000.0
# 4  10   0   0    0  3.59  1.24   9333333.0

# %%
y=fpitch['Avg Annual']
X=fpitch.iloc[:,3:-1]
print(X.shape)
print(y.shape)
# Out:
# (2174, 16)
# (2174,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pcoeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
pcoeff_df
# Out:
#         Coefficient
# GS    192459.317966
# CG    228678.801793
# SHO   369540.160548
# IP     26246.075299
# H     -11872.625668
# ER    -30479.644520
# K      46081.978167
# BB   -114125.987765
# HR    -62931.789136
# W     101315.429649
# L       -691.164559
# SV    111059.520439
# BS     29305.065390
# HLD    -7295.781936
# ERA    14122.861272
# WHIP -221911.360536

# %%
pdf = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
pdf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-ea3bb7c756ad> in <module>
# ----> 1 pdf = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
#       2 pdf
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
# ...

# %%
y_pred = regressor.predict(X_test)

# %%
df2 = df.head(25)
df2.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 3883532.374974728
# Mean Squared Error: 31902911527298.152
# Root Mean Squared Error: 5648266.240829849

# %%
np.sqrt(metrics.mean_squared_error(y_test, y_pred))/fbat['Avg Annual'].mean()
# Out:
# 0.9236887307445958
