# %%
from pymongo import MongoClient
import pandas as pd
import certifi

# %%
s = MongoClient("mongodb+srv://nickkeller21:082z!JOzkH59@baseball.iroer.mongodb.net", tlsCAFile=certifi.where())

# %%
client = MongoClient("mongodb+srv://nickkeller21:082z!JOzkH59@baseball.iroer.mongodb.net", tlsCertificateKeyFile=certifi.where())
db = client["baseball"]
collection = db.baseball

# %%
client = MongoClient("mongodb+srv://nickkeller21:3398gATkf93IIJN6@baseball.iroer.mongodb.net/baseball?retryWrites=true&w=majority", tlsCertificateKeyFile=certifi.where())
db = client.baseball
collection = db.baseball

# %%
uri = "mongodb+srv://nickkeller21:3398gATkf93IIJN6@cluster0.cy1z5.mongodb.net/test"
client = MongoClient(
    uri,
    tlsCAFile=certifi.where()
)
db = client["test"]
collection = db["test"]

# %%
uri = "mongodb+srv://cluster0.cy1z5.mongodb.net/test?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority"
client = MongoClient(uri,
                     tls=True,
                     tlsCertificateKeyFile=r'C:\Users\nickk\Downloads\X509-cert-4586474195399348315.pem')
db = client["test"]
collection = db["test"]

# %%
batter_file = '../data/merge_clean.csv'
pitcher_file = '../data/pitchers_merge_clean.csv'

batter_df = pd.DataFrame(pd.read_csv(batter_file))
pitcher_df = pd.DataFrame(pd.read_csv(pitcher_file))

# %%
group_bat = batter_df.groupby(['espnID', 'playerName', 'photo_url'], as_index=True)['YEAR', 'TEAM', 'WAR', '2B', '3B',
       'AB', 'AVG', 'BB', 'CS', 'GP', 'H', 'HR', 'OBP', 'OPS', 'R', 'RBI',
       'SB', 'SLG', 'SO'].agg(lambda x: list(x))

group_pitch = pitcher_df.groupby(['espnID', 'playerName', 'photo_url'], as_index=True)['SEASON', 'WAR', 'BB', 'BLSV',
       'CG', 'ER', 'ERA', 'GP', 'GS', 'H', 'HLD', 'HR', 'IP', 'L', 'R', 'SHO',
       'SO', 'SV', 'TEAM', 'W', 'WHIP'].agg(lambda x: list(x))
# Out:
# C:\Users\nickk\AppData\Local\ESRI\conda\envs\GIS-Clone\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\nickk\AppData\Local\ESRI\conda\envs\GIS-Clone\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """

# %%
mongo_bat = []

for index,row in group_bat.iterrows():
    curr_dict = {}
    curr_dict['espnID'] = str(index[0])
    curr_dict['playerName'] = index[1]
    curr_dict['imgURL'] = index[2]
    curr_dict['position'] = "batter"
    curr_dict['years'] = {}
    
    YEAR = row['YEAR']
    TEAM = row['TEAM']
    WAR = row['WAR']
    B2 = row['2B']
    B3 = row['3B']
    AB = row['AB']
    AVG = row['AVG']
    BB = row['BB']
    CS = row['CS']
    GP = row['GP']
    H = row['H']
    HR = row['HR']
    OBP = row['OBP']
    OPS = row['OPS']
    R = row['R']
    RBI = row['RBI']
    SB = row['SB']
    SLG = row['SLG']
    SO = row['SO']
     
    for item,value in enumerate(YEAR):
        curr_season = {
            'TEAM' : TEAM[item],
            'WAR': WAR[item],
            '2B' : B2[item],
            '3B' : B3[item],
            'AB' : AB[item],
            'AVG' :AVG[item],
            'BB' : BB[item],
            'CS' : CS[item],
            'GP' : GP[item],
            'H' : H[item],
            'HR' : HR[item],
            'OBP' : OBP[item],
            'OPS' : OPS[item],
            'R' : R[item],
            'RBI' : RBI[item],
            'SB' : SB[item],
            'SLG' : SLG[item],
            'SO' : SO[item]
        }
        curr_dict['years'][str(YEAR[item])]= curr_season
    
    mongo_bat.append(curr_dict.copy())

# %%
mongo_pitch = []

for index,row in group_pitch.iterrows():
    curr_dict = {}
    curr_dict["espnID"] = str(index[0])
    curr_dict['playerName'] = index[1]
    curr_dict['imgURL'] = index[2]
    curr_dict['position'] = 'pitcher'
    curr_dict['years'] = {}
    
    SEASON = row['SEASON']
    WAR = row['WAR']
    BB = row['BB']
    BLSV = row['BLSV']
    CG = row['CG']
    ER = row['ER']
    ERA = row['ERA']
    GP = row['GP']
    GS = row['GS']
    H = row['H']
    HLD = row['HLD']
    HR = row['HR']
    IP = row['IP']
    L = row['L']
    R = row['R']
    SHO = row['SHO']
    SO = row['SO']
    SV = row['SV']
    TEAM = row['TEAM']
    W = row['W']
    WHIP = row['WHIP']
        
    for item,value in enumerate(SEASON):
        curr_season = {
            'WAR' : WAR[item],
            "BB" : BB[item],
            "BLSV" : BLSV[item],
            "CG" : CG[item],
            "ER" : ER[item],
            "ERA" : ERA[item],
            "GP" : GP[item],
            "GS" : GS[item],
            "H" : H[item],
            "HLD" : HLD[item],
            "HR" : HR[item],
            "IP" : IP[item],
            "L" : L[item],
            "R" : R[item],
            "SHO" : SHO[item],
            "SO" : SO[item],
            "SV" : SV[item],
            "TEAM" : TEAM[item],
            "W" : W[item],
            "WHIP" : WHIP[item]
        }
        curr_dict['years'][str(SEASON[item])]= curr_season
    
    mongo_pitch.append(curr_dict.copy())

# %%
mongo_pitch[0]
# Out:
# {'espnID': '5203',
#  'playerName': 'John Lackey',
#  'imgURL': 'https://securea.mlb.com/mlb/images/players/head_shot/407793.jpg',
#  'position': 'pitcher',
#  'years': {'2002': {'WAR': '0.9',
#    'BB': 33,
#    'BLSV': 0,
#    'CG': 1,
#    'ER': 44,
#    'ERA': 3.66,
#    'GP': 18,
#    'GS': 18,
#    'H': 113,
#    'HLD': 0,
#    'HR': 10,
#    'IP': 108.1,
#    'L': 4,
#    'R': 52,
#    'SHO': 0,
#    'SO': 69,
#    'SV': 0,
#    'TEAM': 'ANA',
#    'W': 9,
#    'WHIP': 1.35},
#   '2003': {'WAR': '1',
#    'BB': 66,
#    'BLSV': 0,
#    'CG': 2,
#    'ER': 105,
#    'ERA': 4.63,
#    'GP': 33,
#    'GS': 33,
#    'H': 223,
#    'HLD': 0,
#    'HR': 31,
#    'IP': 204.0,
#    'L': 16,
#    'R': 117,
#    'SHO': 2,
#    'SO': 151,
#    'SV': 0,
#    'TEAM': 'ANA',
#    'W': 10,
#    'WHIP': 1.42},
#   '2004': {'WAR': '1.8',
#    'BB': 60,
#    'BLSV': 0,
#    'CG': 1,
#    'ER': 103,
#    'ERA': 4.67,
#    'GP': 33,
#    'GS': 32,
#    'H': 215,
#    'HLD': 0,
#    'HR': 22,
#    'IP': 198.1,
#    'L': 13,
#    'R': 108,
#    'SHO': 1,
#    'SO': 144,
#    'SV': 0,
#    'TEAM': 'ANA',
#    'W': 14,
#    'WHIP': 1.39},
#   '2005': {'WAR': '4',
#    'BB': 71,
#    'BLSV': 0,
#    'CG': 1,
#    'ER': 80,
#    'ERA': 3.44,
#    'GP': 33,
#    'GS': 33,
#    'H': 208,
#    'HLD': 0,
#    'HR': 13,
#    'IP': 209.0,
#    'L': 5,
#    'R': 85,
#    'SHO': 0,
#    'SO': 199,
#    'SV': 0,
#    'TEAM': 'LAA',
#    'W': 14,
#    'WHIP': 1.33},
#   '2006': {'WAR': '4.3',
#    'BB': 72,
#    'BLSV': 0,
#    'CG': 3,
#    'ER': 86,
#    'ERA': 3.56,
#    'GP': 33,
#    'GS': 33,
#    'H': 203,
#    'HLD': 0,
#    'HR': 14,
#    'IP': 217.2,
#    'L': 11,
#    'R': 98,
#    'SHO': 2,
#    'SO': 190,
#    'SV': 0,
#    'TEAM': 'LAA',
#    'W': 13,
#    'WHIP': 1.26},
#   '2007': {'WAR': '6',
#    'BB': 52,
#    'BLSV': 0,
#    'CG': 2,
#    'ER': 75,
#    'ERA': 3.01,
#    'GP': 33,
#    'GS': 33,
#    'H': 219,
#    'HLD': 0,
#    'HR': 18,
#    'IP': 224.0,
#    'L': 9,
#    'R': 87,
#    'SHO': 2,
#    'SO': 179,
#    'SV': 0,
#    'TEAM': 'LAA',
#    'W': 19,
#    'WHIP': 1.21},
#   '2008': {'WAR': '3.3',
#    'BB': 40,
#    'BLSV': 0,
#    'CG': 3,
#    'ER': 68,
#    'ERA': 3.75,
#    'GP': 24,
#    'GS': 24,
#    'H': 161,
#    'HLD': 0,
#    'HR': 26,
#    'IP': 163.1,
#    'L': 5,
#    'R': 71,
#    'SHO': 0,
#    'SO': 130,
#    'SV': 0,
#    'TEAM': 'LAA',
#    'W': 12,
#    'WHIP': 1.23},
#   '2009': {'WAR': '1.6',
#    'BB': 47,
#    'BLSV': 0,
#    'CG': 1,
#    'ER': 75,
#    'ERA': 3.83,
#    'GP': 27,
#    'GS': 27,
#    'H': 177,
#    'HLD': 0,
#    'HR': 17,
#    'IP': 176.1,
#    'L': 8,
#    'R': 84,
#    'SHO': 1,
#    'SO': 139,
#    'SV': 0,
#    'TEAM': 'LAA',
#    'W': 11,
#    'WHIP': 1.27},
#   '2010': {'WAR': '1.5',
#    'BB': 72,
#    'BLSV': 0,
#    'CG': 0,
#    'ER': 105,
#    'ERA': 4.4,
#    'GP': 33,
#    'GS': 33,
#    'H': 233,
#    'HLD': 0,
#    'HR': 18,
#    'IP': 215.0,
#    'L': 11,
#    'R': 114,
#    'SHO': 0,
#    'SO': 156,
#    'SV': 0,
#    'TEAM': 'BOS',
#    'W': 14,
#    'WHIP': 1.42},
#   '2011': {'WAR': '-2.1',
#    'BB': 56,
#    'BLSV': 0,
#    'CG': 0,
#    'ER': 114,
#    'ERA': 6.41,
#    'GP': 28,
#    'GS': 28,
#    'H': 203,
#    'HLD': 0,
#    'HR': 20,
#    'IP': 160.0,
#    'L': 12,
#    'R': 119,
#    'SHO': 0,
#    'SO': 108,
#    'SV': 0,
#    'TEAM': 'BOS',
#    'W': 12,
#    'WHIP': 1.62},
#   '2013': {'WAR': '2.8',
#    'BB': 40,
#    'BLSV': 0,
#    'CG': 2,
#    'ER': 74,
#    'ERA': 3.52,
#    'GP': 29,
#    'GS': 29,
#    'H': 179,
#    'HLD': 0,
#    'HR': 26,
#    'IP': 189.1,
#    'L': 13,
#    'R': 80,
#    'SHO': 0,
#    'SO': 161,
#    'SV': 0,
#    'TEAM': 'BOS',
#    'W': 10,
#    'WHIP': 1.16},
#   '2014': {'WAR': '1.1',
#    'BB': 47,
#    'BLSV': 0,
#    'CG': 1,
#    'ER': 84,
#    'ERA': 3.82,
#    'GP': 31,
#    'GS': 31,
#    'H': 206,
#    'HLD': 0,
#    'HR': 24,
#    'IP': 198.0,
#    'L': 10,
#    'R': 94,
#    'SHO': 0,
#    'SO': 164,
#    'SV': 0,
#    'TEAM': 'Total',
#    'W': 14,
#    'WHIP': 1.28},
#   '2015': {'WAR': '5.6',
#    'BB': 53,
#    'BLSV': 0,
#    'CG': 1,
#    'ER': 67,
#    'ERA': 2.77,
#    'GP': 33,
#    'GS': 33,
#    'H': 211,
#    'HLD': 0,
#    'HR': 21,
#    'IP': 218.0,
#    'L': 10,
#    'R': 71,
#    'SHO': 0,
#    'SO': 175,
#    'SV': 0,
#    'TEAM': 'STL',
#    'W': 13,
#    'WHIP': 1.21},
#   '2016': {'WAR': '2.5',
#    'BB': 53,
#    'BLSV': 0,
#    'CG': 0,
#    'ER': 70,
#    'ERA': 3.35,
#    'GP': 29,
#    'GS': 29,
#    'H': 146,
#    'HLD': 0,
#    'HR': 23,
#    'IP': 188.1,
#    'L': 8,
#    'R': 74,
#    'SHO': 0,
#    'SO': 180,
#    'SV': 0,
#    'TEAM': 'CHC',
#    'W': 11,
#    'WHIP': 1.06},
#   '2017': {'WAR': '1.2',
#    'BB': 53,
#    'BLSV': 0,
#    'CG': 0,
#    'ER': 87,
#    'ERA': 4.59,
#    'GP': 31,
#    'GS': 30,
#    'H': 165,
#    'HLD': 0,
#    'HR': 36,
#    'IP': 170.2,
#    'L': 12,
#    'R': 93,
#    'SHO': 0,
#    'SO': 149,
#    'SV': 0,
#    'TEAM': 'CHC',
#    'W': 12,
#    'WHIP': 1.28}}}

# %%
collection.insert_many(mongo_bat)

# %%
collection.insert_many(mongo_pitch)

# %%
collection.find_one({"playerName":"Christian Yelich"})
# Out:
# {'_id': ObjectId('620dc8f86cded6561f97f84f'),
#  'espnID': '31283',
#  'playerName': 'Christian Yelich',
#  'imgURL': 'https://securea.mlb.com/mlb/images/players/head_shot/592885.jpg',
#  'position': 'batter',
#  'years': {'2013': {'TEAM': 'MIA',
#    'WAR': 1.4,
#    '2B': 12,
#    '3B': 1,
#    'AB': 240,
#    'AVG': 0.287,
#    'BB': 31,
#    'CS': 0,
#    'GP': 62,
#    'H': 69,
#    'HR': 4,
#    'OBP': 0.37,
#    'OPS': 0.766,
#    'R': 34,
#    'RBI': 16,
#    'SB': 10,
#    'SLG': 0.396,
#    'SO': 66},
#   '2014': {'TEAM': 'MIA',
#    'WAR': 3.6,
#    '2B': 30,
#    '3B': 6,
#    'AB': 582,
#    'AVG': 0.284,
#    'BB': 70,
#    'CS': 7,
#    'GP': 144,
#    'H': 165,
#    'HR': 9,
#    'OBP': 0.362,
#    'OPS': 0.764,
#    'R': 94,
#    'RBI': 54,
#    'SB': 21,
#    'SLG': 0.402,
#    'SO': 137},
#   '2015': {'TEAM': 'MIA',
#    'WAR': 3.5,
#    '2B': 30,
#    '3B': 2,
#    'AB': 476,
#    'AVG': 0.3,
#    'BB': 47,
#    'CS': 5,
#    'GP': 126,
#    'H': 143,
#    'HR': 7,
#    'OBP': 0.366,
#    'OPS': 0.782,
#    'R': 63,
#    'RBI': 44,
#    'SB': 16,
#    'SLG': 0.416,
#    'SO': 101},
#   '2016': {'TEAM': 'MIA',
#    'WAR': 5.3,
#    '2B': 38,
#    '3B': 3,
#    'AB': 578,
#    'AVG': 0.298,
#    'BB': 72,
#    'CS': 4,
#    'GP': 155,
#    'H': 172,
#    'HR': 21,
#    'OBP': 0.376,
#    'OPS': 0.859,
#    'R': 78,
#    'RBI': 98,
#    'SB': 9,
#    'SLG': 0.483,
#    'SO': 138},
#   '2017': {'TEAM': 'MIA',
#    'WAR': 3.9,
#    '2B': 36,
#    '3B': 2,
#    'AB': 602,
#    'AVG': 0.282,
#    'BB': 80,
#    'CS': 2,
#    'GP': 156,
#    'H': 170,
#    'HR': 18,
#    'OBP': 0.369,
#    'OPS': 0.808,
#    'R': 100,
#    'RBI': 81,
#    'SB': 16,
#    'SLG': 0.439,
#    'SO': 137},
#   '2018': {'TEAM': 'MIL',
#    'WAR': 7.6,
#    '2B': 34,
#    '3B': 7,
#    'AB': 574,
#    'AVG': 0.326,
#    'BB': 68,
#    'CS': 4,
#    'GP': 147,
#    'H': 187,
#    'HR': 36,
#    'OBP': 0.402,
#    'OPS': 1.0,
#    'R': 118,
#    'RBI': 110,
#    'SB': 22,
#    'SLG': 0.598,
#    'SO': 135},
#   '2019': {'TEAM': 'MIL',
#    'WAR': 7.1,
#    '2B': 29,
#    '3B': 3,
#    'AB': 489,
#    'AVG': 0.329,
#    'BB': 80,
#    'CS': 2,
#    'GP': 130,
#    'H': 161,
#    'HR': 44,
#    'OBP': 0.429,
#    'OPS': 1.1,
#    'R': 100,
#    'RBI': 97,
#    'SB': 30,
#    'SLG': 0.671,
#    'SO': 118}}}

# %%
query = {"playerName":"Christian Yelich"}
update = {"$set": { "imgURL": "https://upload.wikimedia.org/wikipedia/commons/0/0a/Pete_Davidson_in_2015_%2817073107891%29.jpg" }}

# %%
collection.update_one(query, update)

# %%
client = MongoClient("mongodb+srv://nkeller:3sWES15V4FUKBk1f@cluster0.cy1z5.mongodb.net/test?retryWrites=true&w=majority")
db = client["test"]
collection = db["test"]

# %%
collection.find_one({"playerName":"Rafael Devers"})
# Out:
# {'_id': ObjectId('620dc8f86cded6561f97f879'),
#  'espnID': '33859',
#  'playerName': 'Rafael Devers',
#  'imgURL': 'https://securea.mlb.com/mlb/images/players/head_shot/646240.jpg',
#  'position': 'batter',
#  'years': {'2017': {'TEAM': 'BOS',
#    'WAR': 1.3,
#    '2B': 14,
#    '3B': 0,
#    'AB': 222,
#    'AVG': 0.284,
#    'BB': 18,
#    'CS': 1,
#    'GP': 58,
#    'H': 63,
#    'HR': 10,
#    'OBP': 0.338,
#    'OPS': 0.82,
#    'R': 34,
#    'RBI': 30,
#    'SB': 3,
#    'SLG': 0.482,
#    'SO': 57},
#   '2018': {'TEAM': 'BOS',
#    'WAR': 0.0,
#    '2B': 24,
#    '3B': 0,
#    'AB': 450,
#    'AVG': 0.24,
#    'BB': 38,
#    'CS': 2,
#    'GP': 121,
#    'H': 108,
#    'HR': 21,
#    'OBP': 0.298,
#    'OPS': 0.731,
#    'R': 59,
#    'RBI': 66,
#    'SB': 5,
#    'SLG': 0.433,
#    'SO': 121},
#   '2019': {'TEAM': 'BOS',
#    'WAR': 5.3,
#    '2B': 54,
#    '3B': 4,
#    'AB': 647,
#    'AVG': 0.311,
#    'BB': 48,
#    'CS': 8,
#    'GP': 156,
#    'H': 201,
#    'HR': 32,
#    'OBP': 0.361,
#    'OPS': 0.916,
#    'R': 129,
#    'RBI': 115,
#    'SB': 8,
#    'SLG': 0.555,
#    'SO': 119}}}
